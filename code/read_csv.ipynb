# %%
def read_csv(file):
    import pandas as pd
    import numpy as np
    
    df = pd.read_csv(file)
    #data = np.array(df)
    print(df)

# %%
read_csv('/data3/yunyi/SOAO/M101_SDSS_trial.csv')
# Out:
#             objid          ra        dec         u         g         r  \
# 0    1.237661e+18  210.912783  54.236948  23.95018  22.67423  21.87685
# 1    1.237661e+18  210.892216  54.469863  23.73251  22.78627  23.03053
# 2    1.237661e+18  210.909747  54.232185  25.22007  24.40698  22.85640
# 3    1.237661e+18  210.914170  54.233929  24.78652  24.35643  22.39801
# 4    1.237661e+18  210.892946  54.469797  24.60708  23.68286  23.74250
# ..            ...         ...        ...       ...       ...       ...
# 990  1.237661e+18  211.074402  54.442409  23.48470  24.81913  23.69029
# 991  1.237661e+18  211.075075  54.441724  23.84788  25.10139  23.79144
# 992  1.237661e+18  211.106853  54.428974  26.24042  23.36790  22.03587
# 993  1.237661e+18  211.071243  54.441088  23.38975  26.33141  23.61017
# 994  1.237661e+18  211.080144  54.439916  23.99260  25.51370  23.08524
#
#             i         z
# 0    21.77730  20.86773
# 1    24.31457  22.08082
# 2    22.61024  22.29392
# ...

# %%
read_csv('/data3/yunyi/SOAO/code/M101_SDSS_trial_R.csv')
# Out:
# [[1.23766139e+18 2.10912783e+02 5.42369482e+01 ... 2.17773000e+01
#   2.08677300e+01 2.18652663e+01]
#  [1.23766139e+18 2.10892216e+02 5.44698631e+01 ... 2.43145700e+01
#   2.20808200e+01 2.40999870e+01]
#  [1.23766139e+18 2.10909747e+02 5.42321852e+01 ... 2.26102400e+01
#   2.22939200e+01 2.29938234e+01]
#  ...
#  [1.23766139e+18 2.11106853e+02 5.44289739e+01 ... 2.16584800e+01
#   2.16665600e+01 2.19406472e+01]
#  [1.23766139e+18 2.11071243e+02 5.44410878e+01 ... 2.25232700e+01
#   2.21897900e+01 2.33111574e+01]
#  [1.23766139e+18 2.11080144e+02 5.44399161e+01 ... 2.23988500e+01
#   2.11232900e+01 2.31027435e+01]]
