# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))
plt.imshow(mpimg.imread('/data3/yunyi/SOAO/alignment/M101/plot.png'))

# %%
import subprocess
import numpy as np
from astropy.io.fits.hdu import hdulist
from astropy.io import fits
from astropy.io.fits import getdata
from astropy.io.fits import getheader

# %%
import sep

flux, fluxerr, flag = sep.sum_circle('/data3/yunyi/SOAO/select/NGC3147/Calib-SOAO-NGC3147-20210507-113743-R-60.fits', params=['X_IMAGE'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-017ba58e527b> in <module>
# ----> 1 import sewpy
#       2
#       3 out = pysex.run('/data3/yunyi/SOAO/select/NGC3147/Calib-SOAO-NGC3147-20210507-113743-R-60.fits', params=['X_IMAGE'])
#
# ModuleNotFoundError: No module named 'sewpy'
