# %%
###sky noise standard deviation
###author : Yunyi Choi
###last edit : 20210716


import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits

specdata = fits.open('/data3/yunyi/SOAO/stacked_NGC3147_20201026_r_median.fits')
specdata.info()

spectrum = specdata[0].data
header = specdata[0].header

#print(spectrum)

flux = []
xpos = []

i=833
for j in range(len(spectrum[i])):
    xpos.append(j)
    flux.append(spectrum[i][j])
    
    
num=flux.index(max(flux))
max_f=max(flux)

n=500
sky_flux=flux[1000:2000]
print('sky std is', np.std(sky_flux))

flux = np.array(flux)
xpos = np.array(xpos)


plt.figure(figsize=(10,7))
plt.plot(xpos,flux,c='black')
plt.title('magnitude of NGC2782', fontsize=20)
plt.xlabel('x position', fontsize=15)
plt.ylabel('Flux', fontsize=15)
plt.axvspan(num-70,num+70,facecolor='r', alpha=0.5)
plt.text(num, max_f, max_f,fontsize=15, color='b')
# Out:
# Filename: /data3/yunyi/SOAO/stacked_NGC3147_20201026_r_median.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (2048, 2048)   float64
# sky std is 9.259688113654384
# Text(600, 54741.069269226864, '54741.069269226864')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61502a1b54ff> in <module>
# ----> 1 sky_flux=flux[:300]
#       2 np.std(sky_flux)
#
# NameError: name 'flux' is not defined
