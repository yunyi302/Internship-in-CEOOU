# %%
###image extracting
###author : Yunyi Choi
###last edit : 20210720


import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits

image_data5 = fits.open('/data3/yunyi/SOAO/stacked_NGC3147_20201026_r_mean.fits')

data5=image_data5[0].data
header5=image_data5[0].header

image5=np.array(data5)

print(image5)

max_value = np.percentile(image5,99.8)
min_value = np.percentile(image5,15)

plt.figure(figsize=(13,13))
plt.imshow(image5, cmap='gray', vmax = max_value, vmin = min_value, origin = 'lower')
#plt.xlim(1000,1750)
#plt.ylim(300,1000)
#plt.show()
plt.colorbar()

print('Min:', np.min(image5))
print('Max:', np.max(image5))
print('Mean:', np.mean(image5))
#print('Stdev:', np.std(image)
# Out:
# [[17.72379434 39.21393586 47.17581246 ... 33.91820446 34.34263789
#   26.90387718]
#  [33.58294865 42.36916747 24.19982027 ... 12.49835182 10.85359592
#   22.00106628]
#  [29.6620175  34.72183565 41.39244051 ... 30.09236352 28.75419893
#   30.00807936]
#  ...
#  [13.69084641 35.23199686 47.34828144 ... 34.11696836 43.68588151
#   24.71809422]
#  [50.52916811 32.13550641 40.20377782 ... 28.70552315 18.48278676
#   31.57334214]
#  [23.30701541 38.72663145 29.62723456 ... 33.21886387 32.42535215
#   22.61360471]]
# Min: -347.45279294982316
# Max: 54734.99907893183
# Mean: 30.759353486167228
